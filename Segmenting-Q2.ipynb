# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.10
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/attreys/anaconda3
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.8.3                |   py37hc8dfbb8_1         3.0 MB  conda-forge
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.21.0               |             py_0          58 KB  conda-forge
#     python_abi-3.7             |          1_cp37m           4 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-1.21.0-py_0
#   python_abi         conda-forge/osx-64::python_abi-3.7-1_cp37m
#
# The following packages will be UPDATED:
#
#   conda                      pkgs/main::conda-4.7.10-py37_0 --> conda-forge::conda-4.8.3-py37hc8dfbb8_1
#
#
#
# Downloading and Extracting Packages
# python_abi-3.7       | 4 KB      | ##################################### | 100%
# geopy-1.21.0         | 58 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# conda-4.8.3          | 3.0 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::anaconda==2019.07=py37_0
#   - defaults/osx-64::numba==0.44.1=py37h6440ff4_0
# done
#
# ## Package Plan ##
#
#   environment location: /Users/attreys/anaconda3
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2019.03  |           py37_0           6 KB
#     altair-4.0.1               |             py_0         575 KB  conda-forge
#     anaconda-custom            |           py37_1           3 KB
#     branca-0.4.0               |             py_0          26 KB  conda-forge
#     ca-certificates-2019.11.28 |       hecc5488_0         145 KB  conda-forge
#     certifi-2019.11.28         |   py37hc8dfbb8_1         148 KB  conda-forge
#     folium-0.5.0               |             py_0          45 KB  conda-forge
#     openssl-1.1.1e             |       h0b31af3_0         1.9 MB  conda-forge
#     tbb-2019.8                 |       h770b8ee_0         157 KB  conda-forge
#     vincent-0.4.4              |             py_1          28 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.0 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/osx-64::_anaconda_depends-2019.03-py37_0
#   altair             conda-forge/noarch::altair-4.0.1-py_0
#   branca             conda-forge/noarch::branca-0.4.0-py_0
#   folium             conda-forge/noarch::folium-0.5.0-py_0
#   tbb                conda-forge/osx-64::tbb-2019.8-h770b8ee_0
#   vincent            conda-forge/noarch::vincent-0.4.4-py_1
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2019.5.15-0 --> conda-forge::ca-certificates-2019.11.28-hecc5488_0
#   certifi               pkgs/main::certifi-2019.6.16-py37_0 --> conda-forge::certifi-2019.11.28-py37hc8dfbb8_1
#   openssl              pkgs/main::openssl-1.1.1c-h1de35cc_1 --> conda-forge::openssl-1.1.1e-h0b31af3_0
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2019.07-py37_0 --> custom-py37_1
#
#
#
# Downloading and Extracting Packages
# ca-certificates-2019 | 145 KB    | ##################################### | 100%
# branca-0.4.0         | 26 KB     | ##################################### | 100%
# certifi-2019.11.28   | 148 KB    | ##################################### | 100%
# _anaconda_depends-20 | 6 KB      | ##################################### | 100%
# anaconda-custom      | 3 KB      | ##################################### | 100%
# folium-0.5.0         | 45 KB     | ##################################### | 100%
# altair-4.0.1         | 575 KB    | ##################################### | 100%
# openssl-1.1.1e       | 1.9 MB    | ##################################### | 100%
# tbb-2019.8           | 157 KB    | ##################################### | 100%
# vincent-0.4.4        | 28 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
# !pip install geopy
# Out:
# Collecting geopy
#   Downloading https://files.pythonhosted.org/packages/53/fc/3d1b47e8e82ea12c25203929efb1b964918a77067a874b2c7631e2ec35ec/geopy-1.21.0-py2.py3-none-any.whl (104kB)
#      |████████████████████████████████| 112kB 107kB/s eta 0:00:01
# Collecting geographiclib<2,>=1.49 (from geopy)
#   Downloading https://files.pythonhosted.org/packages/8b/62/26ec95a98ba64299163199e95ad1b0e34ad3f4e176e221c40245f211e425/geographiclib-1.50-py3-none-any.whl
# Installing collected packages: geographiclib, geopy
# Successfully installed geographiclib-1.50 geopy-1.21.0

# %%
import requests
import urllib.request
import time
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from urllib.request import urlopen
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
html = urlopen(url) 
soup = BeautifulSoup(html, 'html.parser')

# %%
tables = soup.find_all('table')

# %%
type(tables)
# Out:
# bs4.element.ResultSet

# %%
req_table=tables[0]

# %%
for i in req_table:
    rows2=req_table.find_all('td')

# %%
len(rows2)
# Out:
# 180

# %%
pincode=[]
burough=[]
neighbourhood=[]
for i in range(0,len(rows2)):
    if(len(rows2[i].findAll('a'))==1):
        pincode.append(rows2[i].findAll('b')[0].text)
        burough.append(rows2[i].findAll('a')[0].get('title'))
        #If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough.
        neighbourhood.append(rows2[i].findAll('a')[0].get('title'))
    elif(len(rows2[i].findAll('a'))>=2):
        for j in range(1,len(rows2[i].findAll('a'))):
            pincode.append(rows2[i].findAll('b')[0].text)
            burough.append(rows2[i].findAll('a')[0].get('title'))
            neighbourhood.append(rows2[i].findAll('a')[j].get('title'))
    else:
        pincode.append(rows2[i].findAll('b')[0].text)
        burough.append('0')
        neighbourhood.append('0')

# %%
type(pincode)
# Out:
# list

# %%
len(pincode)
# Out:
# 252

# %%
len(burough)
# Out:
# 252

# %%
len(neighbourhood)
# Out:
# 252

# %%
import pandas as pd
df_final = pd.DataFrame(
    {'PostalCode': pincode,
     'Borough': burough,
     'Neighborhood': neighbourhood
    })

# %% [markdown]
# Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.

# %%
df_fin=df_final[df_final['Borough']!='0']

# %%
df2=df_fin.groupby("PostalCode").count()['Neighborhood']>1

# %%
df2=df2.reset_index()

# %%
list_pincode_single=df2[df2['Neighborhood']==False]['PostalCode'].tolist()

# %%
list_pincode_multiple=df2[df2['Neighborhood']==True]['PostalCode'].tolist()

# %%
cols={'PostalCode','Borough','Neighborhood'}
k=pd.DataFrame(columns=cols)
for i in range(0,len(df_fin)):
    if(df_fin.iloc[i]['PostalCode'] in list_pincode_single):
        k=k.append(df_fin.iloc[i])

# %%
len(list_pincode_multiple)
# Out:
# 43

# %% [markdown]
# More than one neighborhood can exist in one postal code area. For example, in the table on the Wikipedia page, you will notice that M5A is listed twice and has two neighborhoods: Harbourfront and Regent Park. These two rows will be combined into one row with the neighborhoods separated with a comma as shown in row 11 in the above table.

# %%
pincode2=[]
burough2=[]
neighbourhood2=[]

# %%
for j in range(0,len(list_pincode_multiple)):
        pincode2.append(list_pincode_multiple[j])
        #print(pincode2)
        burough2.append(df_fin[df_fin['PostalCode']==list_pincode_multiple[j]]['Borough'].iloc[0])
        str1=""
        neighbourhood2.append(str1.join(df_fin[df_fin['PostalCode']==list_pincode_multiple[j]]['Neighborhood'].tolist()))

# %%
len(pincode2)
# Out:
# 43

# %%
len(burough2)
# Out:
# 43

# %%
len(neighbourhood2)
# Out:
# 43

# %%
import pandas as pd
df_multipleeq = pd.DataFrame({'PostalCode': pincode2,'Borough': burough2,'Neighborhood': neighbourhood2})

# %%
len(k)
# Out:
# 58

# %%
final=df_multipleeq.append(k)

# %% [markdown]
# In the last cell of your notebook, use the .shape method to print the number of rows of your dataframe.

# %%
final.shape
# Out:
# (101, 3)

# %%
final
# Out:
#                       Borough  \
# 0        Scarborough, Toronto
# 1        Scarborough, Toronto
# 2        Scarborough, Toronto
# 3        Scarborough, Toronto
# 4        Scarborough, Toronto
# 5        Scarborough, Toronto
# 6        Scarborough, Toronto
# 7        Scarborough, Toronto
# 8        Scarborough, Toronto
# 9        Scarborough, Toronto
# 10       Scarborough, Toronto
# 11       Scarborough, Toronto
# 12                 North York
# 13                 North York
# 14                 North York
# 15                 North York
# 16                  East York
# 17        Summerhill, Toronto
# 18           Downtown Toronto
# 19           Downtown Toronto
# 20           Downtown Toronto
# 21           Downtown Toronto
# 22           Downtown Toronto
# 23           Downtown Toronto
# 24           Downtown Toronto
# 25                 North York
# 26                  The Annex
# 27           Downtown Toronto
# 28           Downtown Toronto
# 29           Downtown Toronto
# 30                 North York
# 31          Brockton, Toronto
# 32              York, Toronto
# 33              York, Toronto
# 34                  Etobicoke
# 35                  Etobicoke
# 36                  Etobicoke
# 37                  Etobicoke
# 38                  Etobicoke
# 39                  Etobicoke
# 40                 North York
# 41                  Etobicoke
# 42                  Etobicoke
# 2                  North York
# 3                  North York
# 8      Queen's Park (Toronto)
# 10                  Etobicoke
# 14                 North York
# 19                 North York
# 32                  East York
# 33           Downtown Toronto
# 34              York, Toronto
# 37                  Etobicoke
# 43                The Beaches
# 44           Downtown Toronto
# 45              York, Toronto
# 49       Scarborough, Toronto
# 52                  East York
# 53           Downtown Toronto
# 54           Downtown Toronto
# 58       Scarborough, Toronto
# 59                 North York
# 63                  East York
# 66            Dufferin Street
# 70       Scarborough, Toronto
# 71                 North York
# 74                  East York
# 78   Little Portugal, Toronto
# 85                 North York
# 88               The Danforth
# 99                 North York
# 100                North York
# 101  Gerrard Street (Toronto)
# 104                North York
# 107                North York
# 111                North York
# 112                North York
# 124                North York
# 125                North York
# 126    Lawrence Park, Toronto
# 132             York, Toronto
# 136                North York
# 138        Davisville Village
# 139      Forest Hill, Toronto
# 140                 High Park
# 143                 Etobicoke
# 146                North York
# 148             North Toronto
# 151         Parkdale, Toronto
# 152               Mississauga
# 154                 Etobicoke
# 155      Scarborough, Toronto
# 158        Davisville Village
# 159          Downtown Toronto
# 160        Runnymede, Toronto
# 168       Moore Park, Toronto
# 206          Downtown Toronto
# 207          Downtown Toronto
# 217      Scarborough, Toronto
# 232          Downtown Toronto
# 235       Business reply mail
#
#                                           Neighborhood PostalCode
# 0                       Malvern, TorontoRouge, Toronto        M1B
# 1    Rouge HillPort Union, OntarioHighland Creek, T...        M1C
# 2      GuildwoodMorningside, TorontoWest Hill, Toronto        M1E
# 3          Kennedy Park, TorontoIonviewBirchmount Park        M1K
# 4        Golden Mile, TorontoClairleaOakridge, Toronto        M1L
# 5      Cliffside, TorontoCliffcrestScarborough Village        M1M
# 6                        Birch CliffCliffside, Toronto        M1N
# 7    Dorset ParkWexford HeightsScarborough Town Centre        M1P
# 8                    Wexford, TorontoMaryvale, Toronto        M1R
# 9              Tam O'Shanter, OntarioSullivan, Toronto        M1T
# 10   Milliken, TorontoAgincourt NorthSteeles, Toron...        M1V
# 11                          Steeles, TorontoL'Amoreaux        M1W
# 12                            Don MillsFlemingdon Park        M3C
# 13      Bathurst ManorWilson Heights, TorontoDownsview        M3H
# 14              York University HeightsYork University        M3J
# 15               DownsviewCanadian Forces Base Toronto        M3K
# 16                       Parkview HillWoodbine Gardens        M4B
# 17   RathnellySouth Hill, TorontoForest Hill, Toron...        M4V
# 18                 St. James TownCabbagetown (Toronto)        M4X
# 19                    Regent ParkHarbourfront, Toronto        M5A
# 20          Garden District, TorontoRyerson University        M5B
# 21                Richmond StreetKing Street (Toronto)        M5H
# 22   Harbourfront (Toronto)Union Station (Toronto)T...        M5J
# 23              Toronto Dominion CentreDesign Exchange        M5K
# 24              Commerce CourtHotel Victoria (Toronto)        M5L
# 25                 Bedford Park, TorontoLawrence Manor        M5M
# 26            North Midtown, TorontoYorkville, Toronto        M5R
# 27   Kensington MarketChinatown, TorontoGrange Park...        M5T
# 28   CN TowerKing and SpadinaRailway LandsHarbourfr...        M5V
# 29                  First Canadian PlacePATH (Toronto)        M5X
# 30                      Lawrence ManorLawrence Heights        M6A
# 31                    Parkdale VillageExhibition Place        M6K
# 32                    Mount DennisSilverthorn, Toronto        M6M
# 33                      Runnymede, TorontoThe Junction        M6N
# 34                                   New TorontoMimico        M8V
# 35              Alderwood, TorontoLong Branch, Toronto        M8W
# 36                       The KingswayOld Mill, Toronto        M8X
# 37   Old Mill, TorontoSunnyleaHumber BayMimicoThe Q...        M8Y
# 38                                 MimicoThe Queensway        M8Z
# 39   West Deane ParkPrincess GardensMartin Grove Ro...        M9B
# 40                             HumberleaEmery, Toronto        M9M
# 41   South SteelesSilverstone, TorontoJamestown, To...        M9V
# 42   Clairville, TorontoHumberwoodWoodbine DownsRex...        M9W
# 2                                            Parkwoods        M3A
# 3                                     Victoria Village        M4A
# 8                        Ontario Provincial Government        M7A
# 10                                    Islington Avenue        M9A
# 14                                           Don Mills        M3B
# 19                                          North York        M6B
# 32                                    Woodbine Heights        M4C
# 33                                      St. James Town        M5C
# 34                                  Humewood-Cedarvale        M6C
# 37                                       Markland Wood        M9C
# 43                                         The Beaches        M4E
# 44                                    Downtown Toronto        M5E
# 45                                 Caledonia-Fairbanks        M6E
# 49                                     Woburn, Toronto        M1G
# 52                                             Leaside        M4G
# 53                                          Bay Street        M5G
# 54                                    Downtown Toronto        M6G
# 58                                     Woburn, Toronto        M1H
# 59                                   Hillcrest Village        M2H
# 63                                    Thorncliffe Park        M4H
# 66                                  Dovercourt Village        M6H
# 70                                 Scarborough Village        M1J
# 71                                          Henry Farm        M2J
# 74                                        The Danforth        M4J
# 78                                   Trinity–Bellwoods        M6J
# 85                                     Bayview Village        M2K
# 88                                  Riverdale, Toronto        M4K
# 99                                          York Mills        M2L
# 100                                          Downsview        M3L
# 101                                        The Beaches        M4L
# 104                                Maple Leaf, Toronto        M6L
# 107                                      Humber Summit        M9L
# 111                                        Newtonbrook        M2M
# 112                                          Downsview        M3M
# 124                                Willowdale, Toronto        M2N
# 125                                          Downsview        M3N
# 126                             Lawrence Park, Toronto        M4N
# 132                                    Weston, Toronto        M9N
# 136                                         York Mills        M2P
# 138                                 Davisville Village        M4P
# 139                               Forest Hill, Toronto        M5P
# 140                                       The Junction        M6P
# 143                                          Etobicoke        M9P
# 146                                Willowdale, Toronto        M2R
# 148                                      North Toronto        M4R
# 151                              Roncesvalles, Toronto        M6R
# 152                                        Mississauga        M7R
# 154                                  Kingsview Village        M9R
# 155                                 Agincourt, Toronto        M1S
# 158                                 Davisville Village        M4S
# 159                              University of Toronto        M5S
# 160                                   Swansea, Toronto        M6S
# 168                                Summerhill, Toronto        M4T
# 206                                  Rosedale, Toronto        M4W
# 207                                   Downtown Toronto        M5W
# 217                                        Upper Rouge        M1X
# 232                               Church and Wellesley        M4Y
# 235                                Business reply mail        M7Y

# %%
# !pip install geocoder
# Out:
# Collecting geocoder
#   Downloading https://files.pythonhosted.org/packages/4f/6b/13166c909ad2f2d76b929a4227c952630ebaf0d729f6317eb09cbceccbab/geocoder-1.38.1-py2.py3-none-any.whl (98kB)
#      |████████████████████████████████| 102kB 115kB/s ta 0:00:01
# Requirement already satisfied: future in ./anaconda3/lib/python3.7/site-packages (from geocoder) (0.17.1)
# Requirement already satisfied: click in ./anaconda3/lib/python3.7/site-packages (from geocoder) (7.0)
# Collecting ratelim (from geocoder)
#   Downloading https://files.pythonhosted.org/packages/f2/98/7e6d147fd16a10a5f821db6e25f192265d6ecca3d82957a4fdd592cad49c/ratelim-0.1.6-py2.py3-none-any.whl
# Requirement already satisfied: six in ./anaconda3/lib/python3.7/site-packages (from geocoder) (1.13.0)
# Requirement already satisfied: requests in ./anaconda3/lib/python3.7/site-packages (from geocoder) (2.22.0)
# Requirement already satisfied: decorator in ./anaconda3/lib/python3.7/site-packages (from ratelim->geocoder) (4.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.7/site-packages (from requests->geocoder) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in ./anaconda3/lib/python3.7/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in ./anaconda3/lib/python3.7/site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in ./anaconda3/lib/python3.7/site-packages (from requests->geocoder) (1.25.6)
# Installing collected packages: ratelim, geocoder
# Successfully installed geocoder-1.38.1 ratelim-0.1.6

# %%
import geocoder # import geocoder

# initialize your variable to None
lat_lng_coords = None
postal_code='M5G'
# loop until you get the coordinates
while(lat_lng_coords is None):
    g= geocoder.google('{}, Toronto, Ontario'.format(postal_code))
    lat_lng_coords = g.latlng

latitude = lat_lng_coords[0]
longitude = lat_lng_coords[1]

# %%
pwd
# Out:
# '/Users/attreys'

# %%
df=pd.read_csv('Geospatial_Coordinates.csv')

# %%
df_withlong=final.merge(df,left_on='PostalCode', right_on='Postal Code')

# %%
df_withlong
# Out:
#                       Borough  \
# 0        Scarborough, Toronto
# 1        Scarborough, Toronto
# 2        Scarborough, Toronto
# 3        Scarborough, Toronto
# 4        Scarborough, Toronto
# 5        Scarborough, Toronto
# 6        Scarborough, Toronto
# 7        Scarborough, Toronto
# 8        Scarborough, Toronto
# 9        Scarborough, Toronto
# 10       Scarborough, Toronto
# 11       Scarborough, Toronto
# 12                 North York
# 13                 North York
# 14                 North York
# 15                 North York
# 16                  East York
# 17        Summerhill, Toronto
# 18           Downtown Toronto
# 19           Downtown Toronto
# 20           Downtown Toronto
# 21           Downtown Toronto
# 22           Downtown Toronto
# 23           Downtown Toronto
# 24           Downtown Toronto
# 25                 North York
# 26                  The Annex
# 27           Downtown Toronto
# 28           Downtown Toronto
# 29           Downtown Toronto
# 30                 North York
# 31          Brockton, Toronto
# 32              York, Toronto
# 33              York, Toronto
# 34                  Etobicoke
# 35                  Etobicoke
# 36                  Etobicoke
# 37                  Etobicoke
# 38                  Etobicoke
# 39                  Etobicoke
# 40                 North York
# 41                  Etobicoke
# 42                  Etobicoke
# 43                 North York
# 44                 North York
# 45     Queen's Park (Toronto)
# 46                  Etobicoke
# 47                 North York
# 48                 North York
# 49                  East York
# 50           Downtown Toronto
# 51              York, Toronto
# 52                  Etobicoke
# 53                The Beaches
# 54           Downtown Toronto
# 55              York, Toronto
# 56       Scarborough, Toronto
# 57                  East York
# 58           Downtown Toronto
# 59           Downtown Toronto
# 60       Scarborough, Toronto
# 61                 North York
# 62                  East York
# 63            Dufferin Street
# 64       Scarborough, Toronto
# 65                 North York
# 66                  East York
# 67   Little Portugal, Toronto
# 68                 North York
# 69               The Danforth
# 70                 North York
# 71                 North York
# 72   Gerrard Street (Toronto)
# 73                 North York
# 74                 North York
# 75                 North York
# 76                 North York
# 77                 North York
# 78                 North York
# 79     Lawrence Park, Toronto
# 80              York, Toronto
# 81                 North York
# 82         Davisville Village
# 83       Forest Hill, Toronto
# 84                  High Park
# 85                  Etobicoke
# 86                 North York
# 87              North Toronto
# 88          Parkdale, Toronto
# 89                Mississauga
# 90                  Etobicoke
# 91       Scarborough, Toronto
# 92         Davisville Village
# 93           Downtown Toronto
# 94         Runnymede, Toronto
# 95        Moore Park, Toronto
# 96           Downtown Toronto
# 97           Downtown Toronto
# 98       Scarborough, Toronto
# 99           Downtown Toronto
# 100       Business reply mail
#
#                                           Neighborhood PostalCode Postal Code  \
# 0                       Malvern, TorontoRouge, Toronto        M1B         M1B
# 1    Rouge HillPort Union, OntarioHighland Creek, T...        M1C         M1C
# 2      GuildwoodMorningside, TorontoWest Hill, Toronto        M1E         M1E
# 3          Kennedy Park, TorontoIonviewBirchmount Park        M1K         M1K
# 4        Golden Mile, TorontoClairleaOakridge, Toronto        M1L         M1L
# 5      Cliffside, TorontoCliffcrestScarborough Village        M1M         M1M
# 6                        Birch CliffCliffside, Toronto        M1N         M1N
# 7    Dorset ParkWexford HeightsScarborough Town Centre        M1P         M1P
# 8                    Wexford, TorontoMaryvale, Toronto        M1R         M1R
# 9              Tam O'Shanter, OntarioSullivan, Toronto        M1T         M1T
# 10   Milliken, TorontoAgincourt NorthSteeles, Toron...        M1V         M1V
# 11                          Steeles, TorontoL'Amoreaux        M1W         M1W
# 12                            Don MillsFlemingdon Park        M3C         M3C
# 13      Bathurst ManorWilson Heights, TorontoDownsview        M3H         M3H
# 14              York University HeightsYork University        M3J         M3J
# 15               DownsviewCanadian Forces Base Toronto        M3K         M3K
# 16                       Parkview HillWoodbine Gardens        M4B         M4B
# 17   RathnellySouth Hill, TorontoForest Hill, Toron...        M4V         M4V
# 18                 St. James TownCabbagetown (Toronto)        M4X         M4X
# 19                    Regent ParkHarbourfront, Toronto        M5A         M5A
# 20          Garden District, TorontoRyerson University        M5B         M5B
# 21                Richmond StreetKing Street (Toronto)        M5H         M5H
# 22   Harbourfront (Toronto)Union Station (Toronto)T...        M5J         M5J
# 23              Toronto Dominion CentreDesign Exchange        M5K         M5K
# 24              Commerce CourtHotel Victoria (Toronto)        M5L         M5L
# 25                 Bedford Park, TorontoLawrence Manor        M5M         M5M
# 26            North Midtown, TorontoYorkville, Toronto        M5R         M5R
# 27   Kensington MarketChinatown, TorontoGrange Park...        M5T         M5T
# 28   CN TowerKing and SpadinaRailway LandsHarbourfr...        M5V         M5V
# 29                  First Canadian PlacePATH (Toronto)        M5X         M5X
# 30                      Lawrence ManorLawrence Heights        M6A         M6A
# 31                    Parkdale VillageExhibition Place        M6K         M6K
# 32                    Mount DennisSilverthorn, Toronto        M6M         M6M
# 33                      Runnymede, TorontoThe Junction        M6N         M6N
# 34                                   New TorontoMimico        M8V         M8V
# 35              Alderwood, TorontoLong Branch, Toronto        M8W         M8W
# 36                       The KingswayOld Mill, Toronto        M8X         M8X
# 37   Old Mill, TorontoSunnyleaHumber BayMimicoThe Q...        M8Y         M8Y
# 38                                 MimicoThe Queensway        M8Z         M8Z
# 39   West Deane ParkPrincess GardensMartin Grove Ro...        M9B         M9B
# 40                             HumberleaEmery, Toronto        M9M         M9M
# 41   South SteelesSilverstone, TorontoJamestown, To...        M9V         M9V
# 42   Clairville, TorontoHumberwoodWoodbine DownsRex...        M9W         M9W
# 43                                           Parkwoods        M3A         M3A
# 44                                    Victoria Village        M4A         M4A
# 45                       Ontario Provincial Government        M7A         M7A
# 46                                    Islington Avenue        M9A         M9A
# 47                                           Don Mills        M3B         M3B
# 48                                          North York        M6B         M6B
# 49                                    Woodbine Heights        M4C         M4C
# 50                                      St. James Town        M5C         M5C
# 51                                  Humewood-Cedarvale        M6C         M6C
# 52                                       Markland Wood        M9C         M9C
# 53                                         The Beaches        M4E         M4E
# 54                                    Downtown Toronto        M5E         M5E
# 55                                 Caledonia-Fairbanks        M6E         M6E
# 56                                     Woburn, Toronto        M1G         M1G
# 57                                             Leaside        M4G         M4G
# 58                                          Bay Street        M5G         M5G
# 59                                    Downtown Toronto        M6G         M6G
# 60                                     Woburn, Toronto        M1H         M1H
# 61                                   Hillcrest Village        M2H         M2H
# 62                                    Thorncliffe Park        M4H         M4H
# 63                                  Dovercourt Village        M6H         M6H
# 64                                 Scarborough Village        M1J         M1J
# 65                                          Henry Farm        M2J         M2J
# 66                                        The Danforth        M4J         M4J
# 67                                   Trinity–Bellwoods        M6J         M6J
# 68                                     Bayview Village        M2K         M2K
# 69                                  Riverdale, Toronto        M4K         M4K
# 70                                          York Mills        M2L         M2L
# 71                                           Downsview        M3L         M3L
# 72                                         The Beaches        M4L         M4L
# 73                                 Maple Leaf, Toronto        M6L         M6L
# 74                                       Humber Summit        M9L         M9L
# 75                                         Newtonbrook        M2M         M2M
# 76                                           Downsview        M3M         M3M
# 77                                 Willowdale, Toronto        M2N         M2N
# 78                                           Downsview        M3N         M3N
# 79                              Lawrence Park, Toronto        M4N         M4N
# 80                                     Weston, Toronto        M9N         M9N
# 81                                          York Mills        M2P         M2P
# 82                                  Davisville Village        M4P         M4P
# 83                                Forest Hill, Toronto        M5P         M5P
# 84                                        The Junction        M6P         M6P
# 85                                           Etobicoke        M9P         M9P
# 86                                 Willowdale, Toronto        M2R         M2R
# 87                                       North Toronto        M4R         M4R
# 88                               Roncesvalles, Toronto        M6R         M6R
# 89                                         Mississauga        M7R         M7R
# 90                                   Kingsview Village        M9R         M9R
# 91                                  Agincourt, Toronto        M1S         M1S
# 92                                  Davisville Village        M4S         M4S
# 93                               University of Toronto        M5S         M5S
# 94                                    Swansea, Toronto        M6S         M6S
# 95                                 Summerhill, Toronto        M4T         M4T
# 96                                   Rosedale, Toronto        M4W         M4W
# 97                                    Downtown Toronto        M5W         M5W
# 98                                         Upper Rouge        M1X         M1X
# 99                                Church and Wellesley        M4Y         M4Y
# 100                                Business reply mail        M7Y         M7Y
#
#       Latitude  Longitude
# 0    43.806686 -79.194353
# 1    43.784535 -79.160497
# 2    43.763573 -79.188711
# 3    43.727929 -79.262029
# 4    43.711112 -79.284577
# 5    43.716316 -79.239476
# 6    43.692657 -79.264848
# 7    43.757410 -79.273304
# 8    43.750072 -79.295849
# 9    43.781638 -79.304302
# 10   43.815252 -79.284577
# 11   43.799525 -79.318389
# 12   43.725900 -79.340923
# 13   43.754328 -79.442259
# 14   43.767980 -79.487262
# 15   43.737473 -79.464763
# 16   43.706397 -79.309937
# 17   43.686412 -79.400049
# 18   43.667967 -79.367675
# 19   43.654260 -79.360636
# 20   43.657162 -79.378937
# 21   43.650571 -79.384568
# 22   43.640816 -79.381752
# 23   43.647177 -79.381576
# 24   43.648198 -79.379817
# 25   43.733283 -79.419750
# 26   43.672710 -79.405678
# 27   43.653206 -79.400049
# 28   43.628947 -79.394420
# 29   43.648429 -79.382280
# 30   43.718518 -79.464763
# 31   43.636847 -79.428191
# 32   43.691116 -79.476013
# 33   43.673185 -79.487262
# 34   43.605647 -79.501321
# 35   43.602414 -79.543484
# 36   43.653654 -79.506944
# 37   43.636258 -79.498509
# 38   43.628841 -79.520999
# 39   43.650943 -79.554724
# 40   43.724766 -79.532242
# 41   43.739416 -79.588437
# 42   43.706748 -79.594054
# 43   43.753259 -79.329656
# 44   43.725882 -79.315572
# 45   43.662301 -79.389494
# 46   43.667856 -79.532242
# 47   43.745906 -79.352188
# 48   43.709577 -79.445073
# 49   43.695344 -79.318389
# 50   43.651494 -79.375418
# 51   43.693781 -79.428191
# 52   43.643515 -79.577201
# 53   43.676357 -79.293031
# 54   43.644771 -79.373306
# 55   43.689026 -79.453512
# 56   43.770992 -79.216917
# 57   43.709060 -79.363452
# 58   43.657952 -79.387383
# 59   43.669542 -79.422564
# 60   43.773136 -79.239476
# 61   43.803762 -79.363452
# 62   43.705369 -79.349372
# 63   43.669005 -79.442259
# 64   43.744734 -79.239476
# 65   43.778517 -79.346556
# 66   43.685347 -79.338106
# 67   43.647927 -79.419750
# 68   43.786947 -79.385975
# 69   43.679557 -79.352188
# 70   43.757490 -79.374714
# 71   43.739015 -79.506944
# 72   43.668999 -79.315572
# 73   43.713756 -79.490074
# 74   43.756303 -79.565963
# 75   43.789053 -79.408493
# 76   43.728496 -79.495697
# 77   43.770120 -79.408493
# 78   43.761631 -79.520999
# 79   43.728020 -79.388790
# 80   43.706876 -79.518188
# 81   43.752758 -79.400049
# 82   43.712751 -79.390197
# 83   43.696948 -79.411307
# 84   43.661608 -79.464763
# 85   43.696319 -79.532242
# 86   43.782736 -79.442259
# 87   43.715383 -79.405678
# 88   43.648960 -79.456325
# 89   43.636966 -79.615819
# 90   43.688905 -79.554724
# 91   43.794200 -79.262029
# 92   43.704324 -79.388790
# 93   43.662696 -79.400049
# 94   43.651571 -79.484450
# 95   43.689574 -79.383160
# 96   43.679563 -79.377529
# 97   43.646435 -79.374846
# 98   43.836125 -79.205636
# 99   43.665860 -79.383160
# 100  43.662744 -79.321558
